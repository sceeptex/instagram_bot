# %%
# !pip3 install beautifulsoup4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
# soup = BeautifulSoup(html_doc, 'html.parser')

# %%
# url = 'https://en.wikipedia.org/wiki/List_of_countries_by_greenhouse_gas_emissions'
# req = requests.get(url)
# print(req)

# %%
url = 'https://app.studysmarter.de/trainer/9117718'
req = requests.get(url)
print(req)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.text,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# <html translate="no"><head><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <meta charset="utf-8"/>
# <title>StudySmarter Webapp</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="StudySmarter" property="og:title"/>
# <meta content="StudySmarter learning platform" property="og:description"/>
# <meta content="https://app.studysmarter.de/" property="og:url"/>
# <meta content="assets/logo/studysmarter_og.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="628" property="og:image:height"/>
# <meta content="StudySmarter logo" property="og:image:alt"/>
# <meta content="Die StudySmarter Webapp ist die intelligente Lernplattform fÃ¼r Studenten &amp; SchÃ¼ler. Bessere Noten durch Struktur, Motivation und Effizienz :star: Jetzt anmelden!" name="description"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <link href="assets/logo/favicon.png" rel="icon" type="image/x-icon"/>
# <style type="text/css">@font-face{font-family:'Material Icons';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/materialicons/v128/flUhRq6tzZclQEJ-Vdg-IuiaDsNa.woff) format('woff');}.material-icons{font-family:'Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;font-feature-settings:'liga';}@font-face{font-family:'Material Icons';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/materialicons/v128/flUhRq6tzZclQEJ-Vdg-IuiaDsNcIhQ8tQ.woff2) format('woff2');}.material-icons{font-family:'Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;-webkit-font-feature-settings:'liga';-webkit-font-smoothing:antialiased;}</style>
# <script>
#       const urlParams = new URLSearchParams(window.location.search);
#       const campaignUrl = urlParams.get("campaign-url");
#       if (campaignUrl) {
#         window.location.href = campaignUrl;
#       }
#     </script>
# <style>@charset "UTF-8";html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{line-height:1.15}img{border-style:none}body,h2{margin:0;padding:0}html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}h2{margin-top:20px}h2{margin-bottom:10px}h2{font-size:var(--theme-font-size-7xl)}img{border:0}*,:after,:before{box-sizing:border-box}html{font-size:var(--theme-font-size-sm);-webkit-tap-highlight-color:transparent}body{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:var(--theme-font-size-md);line-height:1.42857143;background-color:var(--theme-background-primary)}img{vertical-align:middle}@page{margin:11mm 17mm!important}body{--theme-background-primary:#fff;--theme-background-primary-rgb:255,255,255;--theme-background-primary-hover:#f0f3fa;--theme-background-primary-hover-rgb:240,243,250;--theme-background-secondary:#f0f3fa;--theme-background-secondary-rgb:240,243,250;--theme-background-secondary-hover:#d9dfe8;--theme-background-secondary-hover-rgb:217,223,232;--theme-background-body:#f7f8fa;--theme-background-body-rgb:247,248,250;--theme-background-body-mobile:#f0f3fa;--theme-background-body-mobile-rgb:240,243,250;--theme-background-card:#fff;--theme-background-card-rgb:255,255,255;--theme-background-input:#f0f3fa;--theme-background-input-rgb:240,243,250;--theme-background-overlay:#fff;--theme-background-overlay-rgb:255,255,255;--theme-background-overlay-hover:#f0f3fa;--theme-background-overlay-hover-rgb:240,243,250;--theme-text-main:#10324c;--theme-text-main-rgb:16,50,76;--theme-text-additional:#65788b;--theme-text-additional-rgb:101,120,139;--theme-color-inactive:#b0bcc8;--theme-color-inactive-rgb:176,188,200;--theme-icon-color:#90a0af;--theme-icon-color-rgb:144,160,175;--theme-icon-color-hover:#65788b;--theme-icon-color-hover-rgb:101,120,139;--theme-color-placeholder:#90a0af;--theme-color-placeholder-rgb:144,160,175;--theme-color-contrast:#fff;--theme-color-contrast-rgb:255,255,255;--theme-border-color:#d9dfe8;--theme-border-color-rgb:217,223,232;--theme-border-color-strong:#90a0af;--theme-border-color-strong-rgb:144,160,175;--theme-shadow-base:#10324c;--theme-shadow-base-rgb:16,50,76;--theme-box-shadow-color:rgba(165,178,205,.5);--theme-box-shadow-color-rgb:165,178,205;--theme-color-primary:#06c;--theme-color-primary-rgb:0,102,204;--theme-color-primary-contrast:#fff;--theme-color-primary-contrast-rgb:255,255,255;--theme-color-accent:#00a5aa;--theme-color-accent-rgb:0,165,170;--theme-color-accent-contrast:#fff;--theme-color-accent-contrast-rgb:255,255,255;--theme-color-badge:#fa3273;--theme-color-badge-rgb:250,50,115;--theme-color-badge-contrast:#fff;--theme-color-badge-contrast-rgb:255,255,255;--theme-color-warning:#f53d3d;--theme-color-warning-rgb:245,61,61;--theme-color-warning-dark:#bc0017;--theme-color-warning-dark-rgb:188,0,23;--theme-color-success:#00c75a;--theme-color-success-rgb:0,199,90;--theme-feedback-color-understood:#00c75a;--theme-feedback-color-understood-rgb:0,199,90;--theme-feedback-color-understood-shade:#e6f9ef;--theme-feedback-color-understood-shade-rgb:230,249,239;--theme-feedback-color-not-sure:#f0ac00;--theme-feedback-color-not-sure-rgb:240,172,0;--theme-feedback-color-not-sure-shade:#fef7e6;--theme-feedback-color-not-sure-shade-rgb:254,247,230;--theme-feedback-color-unclear:#f53d3d;--theme-feedback-color-unclear-rgb:245,61,61;--theme-feedback-color-unclear-shade:#feecec;--theme-feedback-color-unclear-shade-rgb:254,236,236;--theme-feedback-color-trash:#90a0af;--theme-feedback-color-trash-rgb:144,160,175;--theme-feedback-color-unseen:#b0bcc8;--theme-feedback-color-unseen-rgb:176,188,200;--theme-consumer-color:#183162;--theme-consumer-color-rgb:24,49,98;--theme-consumer-color-dark:#082255;--theme-consumer-color-dark-rgb:8,34,85;--theme-consumer-color-contrast:#f0f3fa;--theme-consumer-color-contrast-rgb:240,243,250;--theme-consumer-text-main:#f0f3fa;--theme-consumer-text-main-rgb:240,243,250;--theme-consumer-text-additional:rgba(240,243 ...
# <body>
# <app-root>
# <style>
#         app-root {
#           display: flex;
#           justify-content: center;
#           align-items: center;
#           height: 100vh;
#
#           color: rgb(255, 255, 255);
#           text-transform: uppercase;
#           font-size: 2.5em;
#           text-shadow: 2px 2px 10px rgba(0, 0, 0, 0.2);
#         }
#
#         body {
#           background: #152337;
#           margin: 0;
#         }
#
#         @keyframes dots {
#           50% {
#             transform: translateY(-0.4rem);
#           }
#
#           100% {
#             transform: translateY(0);
#           }
#         }
#
#         h2 {
#           font-family: Proxima Nova, sans-serif;
#           font-weight: 400;
#           text-align: center;
#           font-size: 22px;
#         }
#
#         .d1 {
#           margin-top: 5%;
#           animation: dots 1.5s ease-out infinite;
#           font-size: 30px;
#         }
#
#         .d2 {
#           margin-top: 5%;
#           animation: dots 2s ease-out infinite;
#           animation-delay: 0.5s;
#           font-size: 30px;
#         }
#
#         .d3 {
#           margin-top: 5%;
#           animation: dots 2.5s ease-out infinite;
#           animation-delay: 1s;
#           font-size: 30px;
#           margin-right: 16px;
#         }
#
#         .logo {
#           width: 30%;
#           height: 30%;
#           position: absolute;
#           top: 25%;
#           left: 50%;
#           transform: translateX(-50%) translateY(-30%);
#         }
#         .loading-wrapper {
#           padding: 10px;
#           margin-top: 5%;
#         }
#       </style>
# <div class="loading-wrapper">
# <h2 id="loading-text"></h2>
# <script>
#           let loadingSlogans = [
#             "Loading your good grades",
#             "Drawing your Mind-Map",
#             "Printing your digital documents",
#             "Filling up highlighter ink",
#             "Exams. Exams never change",
#             "Getting ready for you",
#             "Hold on, we need to get dressed",
#             "Yes, yes, we are hurrying",
#             "Time is precious. Thatâs why we are hurrying",
#             "Are you ready? We are",
#             "Stay positive and happy",
#             "Always keep learning",
#             "I got 99 problems but bad grades ain't one",
#           ];
#           document.getElementById("loading-text").innerHTML = loadingSlogans[Math.floor(Math.random() * loadingSlogans.length)];
#         </script>
# </div>
# <span class="d1">.</span>
# <span class="d2">.</span>
# <span class="d3">.</span>
# <!-- Generate random loading slogan -->
# <img alt="StudySmarter logo" class="logo" src="assets/logo/studysmarter_white.svg"/>
# </app-root>
# <script defer="" src="runtime.15f1c9290af298feabc2.js"></script><script defer="" nomodule="" src="polyfills-es5.4571c70d98642862f9b4.js"></script><script defer="" src="polyfills.0adcfaf4d5d605ac4cde.js"></script><script defer="" src="scripts.b306dd7ae3694cfd8910.js"></script><script defer="" src="main.52f882c8d2b9acfbeeea.js"></script>
# <!-- Facebook Pixel Code -->
# <script>
#       !(function (f, b, e, v, n, t, s) {
#         if (f.fbq) return;
#         n = f.fbq = function () {
#           n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments);
#         };
#         if (!f._fbq) f._fbq = n;
#         n.push = n;
#         n.loaded = !0;
#         n.version = '2.0';
#         n.queue = [];
#         t = b.createElement(e);
#         t.async = !0;
#         t.src = v;
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s);
#       })(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '644045809099345');
#       fbq('track', 'PageView');
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=644045809099345&amp;ev=PageView&amp;noscript=1" style="display: none;" width="1">
# </img></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Global site tag (gtag.js) - Google Ads: 775526022 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-775526022"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#
#       gtag('js', new Date());
#       gtag('config', 'UA-109243987-10', { groups: 'fallback' }); // Google Analytics
#       gtag('config', 'UA-109243987-3', { groups: 'de' }); // German conversion
#       gtag('config', 'UA-109243987-6', { groups: 'uk' }); // UK conversion
#       gtag('config', 'UA-109243987-9', { groups: 'us' }); // US conversion
#       gtag('config', 'AW-775526022'); // Google Ads
#       gtag('config', 'G-X913S05V1Q'); // firebase analytics
#     </script>
# <!-- Snap Pixel Code -->
# <script type="text/javascript">
#       (function(e,t,n){if(e.snaptr)return;var a=e.snaptr=function()
#       {a.handleRequest?a.handleRequest.apply(a,arguments):a.queue.push(arguments)};
#       a.queue=[];var s='script';r=t.createElement(s);r.async=!0;
#       r.src=n;var u=t.getElementsByTagName(s)[0];
#       u.parentNode.insertBefore(r,u);})(window,document,
#       'https://sc-static.net/scevent.min.js');
#
#       snaptr('init', 'b699290a-885c-4484-b457-c9e9b0b2f940');
#
#       snaptr('track', 'PAGE_VIEW');
#
#     </script>
# <!-- End Snap Pixel Code -->
# </body></html>

# %%
soup.body
# Out:
# <body>
# <app-root>
# <style>
#         app-root {
#           display: flex;
#           justify-content: center;
#           align-items: center;
#           height: 100vh;
#
#           color: rgb(255, 255, 255);
#           text-transform: uppercase;
#           font-size: 2.5em;
#           text-shadow: 2px 2px 10px rgba(0, 0, 0, 0.2);
#         }
#
#         body {
#           background: #152337;
#           margin: 0;
#         }
#
#         @keyframes dots {
#           50% {
#             transform: translateY(-0.4rem);
#           }
#
#           100% {
#             transform: translateY(0);
#           }
#         }
#
#         h2 {
#           font-family: Proxima Nova, sans-serif;
#           font-weight: 400;
#           text-align: center;
#           font-size: 22px;
#         }
#
#         .d1 {
#           margin-top: 5%;
#           animation: dots 1.5s ease-out infinite;
#           font-size: 30px;
#         }
#
#         .d2 {
#           margin-top: 5%;
#           animation: dots 2s ease-out infinite;
#           animation-delay: 0.5s;
#           font-size: 30px;
#         }
#
#         .d3 {
#           margin-top: 5%;
#           animation: dots 2.5s ease-out infinite;
#           animation-delay: 1s;
#           font-size: 30px;
#           margin-right: 16px;
#         }
#
#         .logo {
#           width: 30%;
#           height: 30%;
#           position: absolute;
#           top: 25%;
#           left: 50%;
#           transform: translateX(-50%) translateY(-30%);
#         }
#         .loading-wrapper {
#           padding: 10px;
#           margin-top: 5%;
#         }
#       </style>
# <div class="loading-wrapper">
# <h2 id="loading-text"></h2>
# <script>
#           let loadingSlogans = [
#             "Loading your good grades",
#             "Drawing your Mind-Map",
#             "Printing your digital documents",
#             "Filling up highlighter ink",
#             "Exams. Exams never change",
#             "Getting ready for you",
#             "Hold on, we need to get dressed",
#             "Yes, yes, we are hurrying",
#             "Time is precious. Thatâs why we are hurrying",
#             "Are you ready? We are",
#             "Stay positive and happy",
#             "Always keep learning",
#             "I got 99 problems but bad grades ain't one",
#           ];
#           document.getElementById("loading-text").innerHTML = loadingSlogans[Math.floor(Math.random() * loadingSlogans.length)];
#         </script>
# </div>
# <span class="d1">.</span>
# <span class="d2">.</span>
# <span class="d3">.</span>
# <!-- Generate random loading slogan -->
# <img alt="StudySmarter logo" class="logo" src="assets/logo/studysmarter_white.svg"/>
# </app-root>
# <script defer="" src="runtime.15f1c9290af298feabc2.js"></script><script defer="" nomodule="" src="polyfills-es5.4571c70d98642862f9b4.js"></script><script defer="" src="polyfills.0adcfaf4d5d605ac4cde.js"></script><script defer="" src="scripts.b306dd7ae3694cfd8910.js"></script><script defer="" src="main.52f882c8d2b9acfbeeea.js"></script>
# <!-- Facebook Pixel Code -->
# <script>
#       !(function (f, b, e, v, n, t, s) {
#         if (f.fbq) return;
#         n = f.fbq = function () {
#           n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments);
#         };
#         if (!f._fbq) f._fbq = n;
#         n.push = n;
#         n.loaded = !0;
#         n.version = '2.0';
#         n.queue = [];
#         t = b.createElement(e);
#         t.async = !0;
#         t.src = v;
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s);
#       })(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '644045809099345');
#       fbq('track', 'PageView');
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=644045809099345&amp;ev=PageView&amp;noscript=1" style="display: none;" width="1">
# </img></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Global site tag (gtag.js) - Google Ads: 775526022 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-775526022"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#
#       gtag('js', new Date());
#       gtag('config', 'UA-109243987-10', { groups: 'fallback' }); // Google Analytics
#       gtag('config', 'UA-109243987-3', { groups: 'de' }); // German conversion
#       gtag('config', 'UA-109243987-6', { groups: 'uk' }); // UK conversion
#       gtag('config', 'UA-109243987-9', { groups: 'us' }); // US conversion
#       gtag('config', 'AW-775526022'); // Google Ads
#       gtag('config', 'G-X913S05V1Q'); // firebase analytics
#     </script>
# <!-- Snap Pixel Code -->
# <script type="text/javascript">
#       (function(e,t,n){if(e.snaptr)return;var a=e.snaptr=function()
#       {a.handleRequest?a.handleRequest.apply(a,arguments):a.queue.push(arguments)};
#       a.queue=[];var s='script';r=t.createElement(s);r.async=!0;
#       r.src=n;var u=t.getElementsByTagName(s)[0];
#       u.parentNode.insertBefore(r,u);})(window,document,
#       'https://sc-static.net/scevent.min.js');
#
#       snaptr('init', 'b699290a-885c-4484-b457-c9e9b0b2f940');
#
#       snaptr('track', 'PAGE_VIEW');
#
#     </script>
# <!-- End Snap Pixel Code -->
# </body>

# %%
from selenium import webdriver

driver = webdriver.Chrome()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_49772/4047744375.py in <module>
# ----> 1 from selenium import webdriver
#       2
#       3 driver = webdriver.Chrome()
#
# ModuleNotFoundError: No module named 'selenium'
